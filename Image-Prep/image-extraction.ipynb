# %% [markdown]
# #### Image Extraction (Add dataset, feature, and tools folder next to this)

# %%
fn_occ_top_30 = [
'3_5_396','3_6_433','3_4_356','3_6_441','3_8_530',
'3_2_290','3_2_302','3_2_303','3_3_327','3_3_326',
'3_3_341','3_3_309','3_3_337','3_4_351','3_5_398',
'3_5_420','3_5_397','3_5_419','3_7_509','3_8_534',
'3_8_554','3_8_529','3_8_550','3_8_555','3_8_528',
'3_8_532','3_8_552','3_9_617','3_9_616','3_9_587',
]

fp_occ_top_30 = [
'3_2_295','3_10_648','3_1_248','3_9_585','3_8_545',
'3_7_506','3_3_315','3_1_266','3_2_296','3_2_294',
'3_3_325','3_4_358','3_4_348','3_4_362','3_4_363',
'3_5_402','3_5_422','3_5_408','3_5_399','3_5_403',
'3_6_477','3_6_462','3_7_510','3_8_531','3_8_551',
'3_9_615','3_9_586','3_9_611','3_9_625','3_9_588',
]

tp_occ_top_30 = [
'3_15_831','3_15_836','3_6_443','3_11_708','3_16_930',
'3_15_837','3_10_682','3_10_678','3_16_929','3_1_267',
'3_11_709','3_4_380','3_16_943','3_4_355','3_4_352',
'3_6_434','3_19_995','3_4_354','3_16_918','3_18_970',
'3_16_931','3_15_862','3_4_350','3_4_353','3_16_933',
'3_4_349','3_17_966','3_16_902','3_16_938','3_3_328',
]

tn_occ_top_30 = [
'3_2_281','3_7_497','3_12_782','3_12_783','3_8_537',
'3_10_639','3_6_430','3_8_538','3_12_789','3_2_280',
'3_7_496','3_12_770','3_8_548','3_10_641','3_14_818',
'3_12_796','3_10_640','3_11_717','3_12_794','3_9_570',
'3_17_960','3_1_229','3_12_786','3_12_737','3_12_752',
'3_17_959','3_12_795','3_12_793','3_10_642','3_11_697',
]

# %%
fn_occ_ext_top_30 = [
'3_5_396','3_6_441','3_8_550','3_8_530','3_3_327',
'3_6_433','3_4_356','3_7_509','3_9_616','3_5_398',
'3_2_290','3_2_302','3_2_303','3_3_326','3_3_341',
'3_3_309','3_3_337','3_4_351','3_5_420','3_5_397',
'3_5_419','3_8_534','3_8_554','3_8_529','3_8_555',
'3_8_528','3_8_532','3_8_552','3_9_617','3_9_587',
]

fp_occ_ext_top_30 = [
'3_2_295','3_10_648','3_8_545','3_8_551','3_7_506',
'3_2_294','3_3_315','3_9_585','3_5_422','3_1_248',
'3_4_358','3_9_611','3_1_266','3_2_296','3_3_325',
'3_4_348','3_4_362','3_4_363','3_5_402','3_5_408',
'3_5_399','3_5_403','3_6_477','3_6_462','3_7_510',
'3_8_531','3_9_615','3_9_586','3_9_625','3_9_588',
]

tp_occ_ext_top_30 = [
'3_15_831','3_11_708','3_15_836','3_10_682','3_1_267',
'3_11_709','3_6_443','3_4_355','3_10_678','3_4_349',
'3_6_434','3_4_354','3_16_938','3_6_437','3_16_930',
'3_16_929','3_15_837','3_15_862','3_7_507','3_16_943',
'3_6_440','3_16_922','3_15_830','3_10_691','3_10_675',
'3_16_941','3_10_689','3_16_940','3_4_380','3_18_970',
]

tn_occ_ext_top_30 = [
'3_8_537','3_8_538','3_7_497','3_2_280','3_7_496',
'3_12_770','3_12_789','3_10_639','3_14_818','3_12_782',
'3_12_786','3_10_640','3_18_976','3_2_281','3_10_638',
'3_5_394','3_9_566','3_10_641','3_12_783','3_10_642',
'3_6_475','3_12_773','3_12_785','3_16_927','3_15_894',
'3_2_285','3_8_548','3_4_345','3_6_430','3_7_483',
]

subsets = ['FN', 'FP', 'TP', 'TN']

# %%
[fn_occ_top_30[2]]
# Out:
# ['3_4_356']

# %%
tp_occ_combined = [
    '3_15_831', '3_15_836', '3_6_443', '3_11_708', '3_16_930',
    '3_15_837', '3_10_682', '3_10_678', '3_16_929', '3_1_267',
    '3_11_709', '3_4_380', '3_16_943', '3_4_355', '3_4_352',
    '3_6_434', '3_19_995', '3_4_354', '3_16_918', '3_18_970',
    '3_16_931', '3_15_862', '3_4_350', '3_4_353', '3_16_933',
    '3_4_349', '3_17_966', '3_16_902', '3_16_938', '3_3_328',
    '3_6_437', '3_7_507', '3_6_440', '3_16_922', '3_15_830',
    '3_10_691', '3_10_675', '3_16_941', '3_10_689', '3_16_940'
]

tn_occ_combined = [
    '3_2_281', '3_7_497', '3_12_782', '3_12_783', '3_8_537',
    '3_10_639', '3_6_430', '3_8_538', '3_12_789', '3_2_280',
    '3_7_496', '3_12_770', '3_8_548', '3_10_641', '3_14_818',
    '3_12_796', '3_10_640', '3_11_717', '3_12_794', '3_9_570',
    '3_17_960', '3_1_229', '3_12_786', '3_12_737', '3_12_752',
    '3_17_959', '3_12_795', '3_12_793', '3_10_642', '3_11_697',
    '3_18_976', '3_10_638', '3_5_394', '3_9_566', '3_6_475',
    '3_12_773', '3_12_785', '3_16_927', '3_15_894', '3_2_285',
    '3_4_345', '3_7_483',
]

# %% [markdown]
# ### Bounding Box Frames (Local)

# %%
import numpy as np
import cv2
import os
import pickle
import pandas as pd
from tqdm import tqdm

from dataset.PIE_API import PIE
from tools.video_utils import VideoLoader
from tools.visualisation import draw_bbox
from tools.box_utils import jitter_bbox, squarify_bbox

# CONFIGURATION
DATASET_DIR = r"C:\Users\dthq657\OneDrive - University of Leeds\Research\Datasets\PIE"
CLIPS_DIR   = os.path.join(DATASET_DIR, "PIE_clips")
DB_PATH     = os.path.join(DATASET_DIR, "data_cache", "pie_database.pkl")
TARGET_DIM  = (224, 224)
SAVE_DIR    = "../Bounding-Box"
SAVE_TOGGLE = False ### Change Toggle to Save
os.makedirs(SAVE_DIR, exist_ok=True)

ATTR_CSVS = {
    "FN": "../Data-Prep/annot-data/PIE_annot_attrb_val_fn.csv",
    "FP": "../Data-Prep/annot-data/PIE_annot_attrb_val_fp.csv",
    "TP": "../Data-Prep/annot-data/PIE_annot_attrb_val_tp.csv",
    "TN": "../Data-Prep/annot-data/PIE_annot_attrb_val_tn.csv"
}


def show_local_pedestrian_clip(subset="FP", ped_id="3_2_295", frames_to_show=32, save_output=SAVE_TOGGLE):
    print(f"🎬 Generating local clip for {subset} → {ped_id}")

    if not os.path.isfile(DB_PATH):
        print("⚠️ PIE database not found — generating...")
        dataset = PIE(data_path=DATASET_DIR)
        dataset.generate_database()
    data = pickle.load(open(DB_PATH, "rb"))

    attr_path = ATTR_CSVS.get(subset)
    attr_df = pd.read_csv(attr_path)
    row = attr_df[attr_df["id"] == ped_id]
    critical_point = int(row["critical_point"].iloc[0])

    set_id, vid_id, ped_num = ped_id.split("_")
    set_name = f"set0{set_id[-1]}" if not set_id.startswith("set") else set_id
    video_name = f"video_{int(vid_id):04d}"
    video_path = os.path.join(CLIPS_DIR, set_name, f"{video_name}.mp4")
    video = VideoLoader(video_path)
    annots = data[set_name][video_name]["ped_annotations"].get(ped_id)
    frames = annots["frames"]

    crit_idx = frames.index(critical_point)
    start_idx = max(0, crit_idx - (frames_to_show - 1))
    seq_frames = frames[start_idx:crit_idx + 1]

    if save_output:
        ped_outdir = os.path.join(SAVE_DIR, f"{subset}/{ped_id}")
        os.makedirs(ped_outdir, exist_ok=True)
        out_path = os.path.join(ped_outdir, f"{subset}_{ped_id}_local.mp4")
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        video_writer = cv2.VideoWriter(out_path, fourcc, 10, TARGET_DIM)
        print(f"💾 Saving cropped video to {out_path}")

    # Step 4: Main frame loop
    for frame_idx in seq_frames:
        frame = video[frame_idx]
        t = annots["frames"].index(frame_idx)
        bbox = list(map(int, annots["bbox"][t][0:4]))

        # Expand + squarify for crop
        jitter_box = jitter_bbox(video.size, [bbox.copy()], mode="enlarge", ratio=1.0)[0]
        local_box = squarify_bbox(jitter_box, 1.0, frame.shape[1])
        local_box = tuple(map(int, local_box[0:4]))

        local_img = frame[local_box[1]:local_box[3], local_box[0]:local_box[2]]
        if local_img.size == 0:
            continue

        local_resized = cv2.resize(local_img, TARGET_DIM)

        pad_ratio = 0.0  # 10% padding relative to bbox size
        x1, y1, x2, y2 = bbox
        w, h = x2 - x1, y2 - y1
        pad_x, pad_y = w * pad_ratio, h * pad_ratio
        padded_box = [x1 - pad_x, y1 - pad_y, x2 + pad_x, y2 + pad_y]

        # Map to resized crop coordinates
        scale_x = TARGET_DIM[0] / (local_box[2] - local_box[0])
        scale_y = TARGET_DIM[1] / (local_box[3] - local_box[1])
        mapped_box = [
            (padded_box[0] - local_box[0]) * scale_x,
            (padded_box[1] - local_box[1]) * scale_y,
            (padded_box[2] - local_box[0]) * scale_x,
            (padded_box[3] - local_box[1]) * scale_y,
        ]

        # Clamp to image boundaries
        mapped_box = [max(0, mapped_box[0]), max(0, mapped_box[1]),
                    min(TARGET_DIM[0], mapped_box[2]), min(TARGET_DIM[1], mapped_box[3])]

        # Draw per-frame adaptive box
        annotated = draw_bbox(local_resized.copy(), mapped_box,
                            caption=f"{ped_id}", thickness=2, color=(255, 0, 0))
        cv2.imshow("Local Pedestrian View", annotated)

        if save_output:
            video_writer.write(annotated)
            cv2.imwrite(os.path.join(ped_outdir, f"frame_{frame_idx}.jpg"), annotated)

        key = cv2.waitKey(60)
        if key == ord("q"):
            break

    cv2.destroyAllWindows()
    if save_output:
        video_writer.release()
        print(f"✅ Saved to: {out_path}")

if __name__ == "__main__":
    subsets = ['FN', 'FP', 'TP', 'TN']
    for subset in subsets:
        ped_set = []
        if subset == 'FN': ped_set = fn_occ_top_30
        elif subset == 'FP': ped_set = fp_occ_top_30
        elif subset == 'TP': ped_set = tp_occ_combined
        elif subset == 'TN': ped_set = tn_occ_combined

        for ped in ped_set:
            show_local_pedestrian_clip(subset=subset, ped_id=ped, frames_to_show=32, save_output=SAVE_TOGGLE)
# Out:
# 🎬 Generating local clip for FN → 3_5_396
# 🎬 Generating local clip for FN → 3_6_433
# 🎬 Generating local clip for FN → 3_4_356
# 🎬 Generating local clip for FN → 3_6_441
# 🎬 Generating local clip for FN → 3_8_530
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 129
#     126 elif subset == 'TN': ped_set = tn_occ_combined
#     128 for ped in ped_set:
# --> 129     show_local_pedestrian_clip(subset=subset, ped_id=ped, frames_to_show=32, save_output=SAVE_TOGGLE)
#
# Cell In[5], line 110, in show_local_pedestrian_clip(subset, ped_id, frames_to_show, save_output)
#     107     video_writer.write(annotated)
#     108     cv2.imwrite(os.path.join(ped_outdir, f"frame_{frame_idx}.jpg"), annotated)
# --> 110 key = cv2.waitKey(60)
#     111 if key == ord("q"):
#     112     break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Body Pose Frames (Local)

# %%
import os
import sys
import cv2
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm
import importlib
YOLO_ROOT = os.path.join(os.getcwd(), "feature", "yolov7pose")

from dataset.PIE_API import PIE
from tools.video_utils import VideoLoader
from tools.pose_utils import draw_body_keypoints
from tools.box_utils import jitter_bbox, squarify_bbox, calculate_iou
from tools.visualisation import draw_bbox

sys.modules["utils"] = importlib.import_module("feature.yolov7pose.utils")
sys.modules["models"] = importlib.import_module("feature.yolov7pose.models")

from feature.yolov7pose._interface import PoseEstimator

DATASET_DIR   = r"C:\Users\dthq657\OneDrive - University of Leeds\Research\Datasets\PIE"
CLIPS_DIR     = os.path.join(DATASET_DIR, "PIE_clips")
DB_PATH       = os.path.join(DATASET_DIR, "data_cache", "pie_database.pkl")
OUTPUT_DIR    = r"../Body-Pose"
TARGET_DIM    = (256,256)
SAVE_TOGGLE = False

os.makedirs(OUTPUT_DIR, exist_ok=True)

ATTR_CSVS = {
    "FN": "../Data-Prep/annot-data/PIE_annot_attrb_val_fn.csv",
    "FP": "../Data-Prep/annot-data/PIE_annot_attrb_val_fp.csv",
    "TP": "../Data-Prep/annot-data/PIE_annot_attrb_val_tp.csv",
    "TN": "../Data-Prep/annot-data/PIE_annot_attrb_val_tn.csv"
}

Pose = PoseEstimator(
    weights=os.path.join(YOLO_ROOT, "weights_pose.pt"),
    device="cpu"
)

dataset = PIE(data_path=DATASET_DIR)
if not os.path.isfile(DB_PATH):
    dataset.generate_database()
data = pickle.load(open(DB_PATH, "rb"))

def extract_pose_frames(subset, ped_id, frames_to_show=32, save_output=True):
    print(f"Extracting pose → {subset}/{ped_id}")
    attr_path = ATTR_CSVS.get(subset)
    attr_df = pd.read_csv(attr_path)
    row = attr_df[attr_df["id"] == ped_id]

    if row.empty:
        print("Pedestrian not found")
        return

    critical_point = int(row["critical_point"].iloc[0])
    set_id, vid_id, ped_num = ped_id.split("_")
    set_name = f"set0{set_id[-1]}" if not set_id.startswith("set") else set_id
    video_name = f"video_{int(vid_id):04d}"
    video_path = os.path.join(CLIPS_DIR, set_name, f"{video_name}.mp4")
    video = VideoLoader(video_path)

    annots = data[set_name][video_name]["ped_annotations"].get(ped_id)
    frames = annots["frames"]
    crit_idx = frames.index(critical_point)
    start_idx = max(0, crit_idx - (frames_to_show - 1))
    seq_frames = frames[start_idx:crit_idx + 1]

    if save_output:
        ped_outdir = os.path.join(OUTPUT_DIR, subset, ped_id)
        os.makedirs(ped_outdir, exist_ok=True)

    for frame_idx in seq_frames:
        frame = video[frame_idx]
        t = annots["frames"].index(frame_idx)
        bbox = list(map(int, annots["bbox"][t][0:4]))
        jitter_box = jitter_bbox(video.size, [bbox.copy()], mode="enlarge", ratio=1.0)[0]
        local_box = squarify_bbox(jitter_box, 1.0, frame.shape[1])
        local_box = tuple(map(int, local_box[0:4]))
        local_img = frame[
            local_box[1]:local_box[3],
            local_box[0]:local_box[2]
        ]

        if local_img.size == 0:
            continue
        safe_resized = cv2.resize(local_img, TARGET_DIM)
        scale_x = TARGET_DIM[0] / (local_box[2] - local_box[0])
        scale_y = TARGET_DIM[1] / (local_box[3] - local_box[1])
        mapped_box = [
            (bbox[0] - local_box[0]) * scale_x,
            (bbox[1] - local_box[1]) * scale_y,
            (bbox[2] - local_box[0]) * scale_x,
            (bbox[3] - local_box[1]) * scale_y
        ]
        mapped_box = [
            max(0, mapped_box[0]),
            max(0, mapped_box[1]),
            min(TARGET_DIM[0], mapped_box[2]),
            min(TARGET_DIM[1], mapped_box[3])
        ]

        _, output_data = Pose.run(safe_resized, draw_pose=False)

        ped_keypoints = None
        maxIOU = 0

        for pose in output_data:
            for det_index, (*xyxy, conf, cls) in enumerate(pose[:, :6]):
                pose_box = [
                    int(xyxy[0]),
                    int(xyxy[1]),
                    int(xyxy[2]),
                    int(xyxy[3])
                ]
                kpts = pose[det_index, 6:].cpu().numpy()
                iou = calculate_iou(pose_box, mapped_box)
                if iou > maxIOU:
                    maxIOU = iou
                    ped_keypoints = kpts

        annotated = safe_resized.copy()

        # DRAW SKELETON
        if ped_keypoints is not None and maxIOU > 0.3:
            annotated = draw_body_keypoints(annotated, ped_keypoints)

        # DRAW BBOX OVERLAY
        annotated = draw_bbox(
            annotated,
            mapped_box,
            caption=ped_id,
            thickness=2,
            color=(255,0,0)
        )

        cv2.imshow("Pose + BBox", annotated)

        if save_output:
            cv2.imwrite(
                os.path.join(
                    ped_outdir,
                    f"frame_{frame_idx}_pose.jpg"
                ),
                annotated
            )
        if cv2.waitKey(40) == ord("q"):
            break

    cv2.destroyAllWindows()
    print(f"Finished {subset}/{ped_id}")


# MAIN LOOP
if __name__ == "__main__":
    subsets = ["FN","FP","TP","TN"]
    for subset in subsets:
        if subset == "FN": ped_set = fn_occ_top_30
        elif subset == "FP": ped_set = fp_occ_top_30
        elif subset == "TP": ped_set = tp_occ_combined
        elif subset == "TN": ped_set = tn_occ_combined
        else: ped_set = []

        for ped in ped_set:
            extract_pose_frames(
                subset=subset,
                ped_id=ped,
                frames_to_show=32,
                save_output=SAVE_TOGGLE)
# Out:
# Fusing layers...
# Extracting pose → FN/3_5_396
# c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4383.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Finished FN/3_5_396
# Extracting pose → FN/3_6_433
# Finished FN/3_6_433
# Extracting pose → FN/3_4_356
# Finished FN/3_4_356
# Extracting pose → FN/3_6_441
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 167
#     164 else: ped_set = []
#     166 for ped in ped_set:
# --> 167     extract_pose_frames(
#     168         subset=subset,
#     169         ped_id=ped,
#     170         frames_to_show=32,
#     171         save_output=SAVE_TOGGLE)
#
# Cell In[7], line 105, in extract_pose_frames(subset, ped_id, frames_to_show, save_output)
#      92 mapped_box = [
#      93     (bbox[0] - local_box[0]) * scale_x,
#      94     (bbox[1] - local_box[1]) * scale_y,
#      95     (bbox[2] - local_box[0]) * scale_x,
#      96     (bbox[3] - local_box[1]) * scale_y
#      97 ]
#      98 mapped_box = [
#      99     max(0, mapped_box[0]),
#     100     max(0, mapped_box[1]),
#     101     min(TARGET_DIM[0], mapped_box[2]),
#     102     min(TARGET_DIM[1], mapped_box[3])
#     103 ]
# --> 105 _, output_data = Pose.run(safe_resized, draw_pose=False)
#     107 ped_keypoints = None
#     108 maxIOU = 0
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\yolov7pose\_interface.py:42, in PoseEstimator.run(self, frame, prepration, draw_pose, save_conf, line_thickness, hide_labels, hide_conf)
#      39     image = frame
#      41 with torch.no_grad():  #get predictions
# ---> 42     output_data, _ = self.model(image)
#      44 output_data = non_max_suppression_kpt(output_data,   #Apply non max suppression
#      45                             0.05, #25,   # Conf. Threshold.
#      46                             0.55, # IoU Threshold.
#      47                             nc=self.model.yaml['nc'], # Number of classes.
#      48                             nkpt=self.model.yaml['nkpt'], # Number of keypoints.
#      49                             kpt_label=True)
#      51 # output = output_to_keypoint(output_data)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\yolov7pose\models\yolo.py:514, in Model.forward(self, x, augment, profile)
#     512     return torch.cat(y, 1), None  # augmented inference, train
#     513 else:
# --> 514     return self.forward_once(x, profile)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\yolov7pose\models\yolo.py:540, in Model.forward_once(self, x, profile)
#     537         dt.append((time_synchronized() - t) * 100)
#     538         print('%10.1f%10.0f%10.1fms %-40s' % (o, m.np, dt[-1], m.type))
# --> 540     x = m(x)  # run
#     542     y.append(x if m.i in self.save else None)  # save output
#     544 if profile:
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\yolov7pose\models\common.py:111, in Conv.fuseforward(self, x)
#     110 def fuseforward(self, x):
# --> 111     return self.act(self.conv(x))
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\conv.py:553, in Conv2d.forward(self, input)
#     552 def forward(self, input: Tensor) -> Tensor:
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#     535 if self.padding_mode != "zeros":
#     536     return F.conv2d(
#     537         F.pad(
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    545         self.groups,
#     546     )
# --> 548 return F.conv2d(
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     550 )
#
# KeyboardInterrupt:

# %% [markdown]
# #### Optical Flow (Local)

# %%
import os
import cv2
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torchvision.transforms as T
from torchvision.models.optical_flow import raft_large
from torchvision.utils import flow_to_image

from dataset.PIE_API import PIE
from tools.video_utils import VideoLoader
from tools.visualisation import draw_bbox
from tools.box_utils import jitter_bbox, squarify_bbox

# === CONFIGURATION ===
DATASET_DIR = r"C:\Users\dthq657\OneDrive - University of Leeds\Research\Datasets\PIE"
CLIPS_DIR   = os.path.join(DATASET_DIR, "PIE_clips")
DB_PATH     = os.path.join(DATASET_DIR, "data_cache", "pie_database.pkl")

SAVE_DIR    = "../Optical-Flow"
os.makedirs(SAVE_DIR, exist_ok=True)

SAVE_OUTPUT = False

ATTR_CSVS = {
    "FN": "../Data-Prep/annot-data/PIE_annot_attrb_val_fn.csv",
    "FP": "../Data-Prep/annot-data/PIE_annot_attrb_val_fp.csv",
    "TP": "../Data-Prep/annot-data/PIE_annot_attrb_val_tp.csv",
    "TN": "../Data-Prep/annot-data/PIE_annot_attrb_val_tn.csv"
}

# === RAFT MODEL ===
device     = "cuda" if torch.cuda.is_available() else "cpu"
raft_model = raft_large(pretrained=True, progress=False).to(device).eval()

def preprocess_frame(frame):
    transforms = T.Compose([
        T.ToTensor(),
        T.ConvertImageDtype(torch.float32),
        T.Normalize(mean=0.5, std=0.5),
        T.Resize(size=(520, 960)),
    ])
    return transforms(frame).to(device)

def compute_raft_optical_flow(prev_frame, next_frame):
    with torch.no_grad():
        flow     = raft_model(prev_frame.unsqueeze(0), next_frame.unsqueeze(0))[-1]
        flow_img = flow_to_image(flow[0]).byte().permute(1, 2, 0).cpu().numpy()
    return flow_img

# === PIE DATABASE ===
if not os.path.isfile(DB_PATH):
    print("Generating PIE database...")
    dataset = PIE(data_path=DATASET_DIR)
    dataset.generate_database()

data = pickle.load(open(DB_PATH, "rb"))


def extract_flow_frames_local(subset="FP", ped_id="3_2_295", frames_to_show=32):

    print(f"Processing local optical flow {subset} → {ped_id}")

    attr_df = pd.read_csv(ATTR_CSVS[subset])
    row     = attr_df[attr_df["id"] == ped_id]

    if len(row) == 0:
        print("Pedestrian not found in CSV")
        return

    critical_point = int(row["critical_point"].iloc[0])

    set_id, vid_id, ped_num = ped_id.split("_")
    set_name   = f"set0{set_id[-1]}" if not set_id.startswith("set") else set_id
    video_name = f"video_{int(vid_id):04d}"

    video_path = os.path.join(CLIPS_DIR, set_name, f"{video_name}.mp4")
    video      = VideoLoader(video_path)

    annots = data[set_name][video_name]["ped_annotations"].get(ped_id)
    frames = annots["frames"]

    crit_idx   = frames.index(critical_point)
    start_idx  = max(0, crit_idx - (frames_to_show - 1))
    seq_frames = frames[start_idx:crit_idx + 1]

    ped_outdir = os.path.join(SAVE_DIR, f"{subset}/{ped_id}_flow_local")
    if SAVE_OUTPUT:
        os.makedirs(ped_outdir, exist_ok=True)

    TARGET_DIM = (224, 224)
    prev_frame = None

    for frame_idx in seq_frames:
        frame = video[frame_idx]
        t     = annots["frames"].index(frame_idx)
        bbox  = list(map(int, annots["bbox"][t][0:4]))

        frame_h, frame_w = frame.shape[:2]
        x1, y1, x2, y2  = bbox

        # === Local context crop — jitter + squarify matching model input pipeline ===
        jitter_box = jitter_bbox(video.size, [bbox.copy()], mode="enlarge", ratio=1.0)[0]
        local_box  = squarify_bbox(jitter_box, 1.0, frame_w)
        local_box  = tuple(map(int, local_box[0:4]))

        local_img = frame[
            local_box[1]:local_box[3],
            local_box[0]:local_box[2]
        ]

        if local_img.size == 0:
            prev_frame = frame
            continue

        # === Compute RAFT on full frames — preserves scene-level motion context ===
        ref_frame = prev_frame if prev_frame is not None else frame
        flow_full = compute_raft_optical_flow(
            preprocess_frame(ref_frame),
            preprocess_frame(frame)
        )

        # Resize flow output to match full frame dimensions
        flow_full_resized = cv2.resize(
            flow_full,
            (frame_w, frame_h),
            interpolation=cv2.INTER_LINEAR
        )

        # === Crop flow to local box then resize to 224×224 ===
        flow_local = flow_full_resized[
            local_box[1]:local_box[3],
            local_box[0]:local_box[2]
        ]
        flow_local_resized = cv2.resize(
            flow_local,
            TARGET_DIM,
            interpolation=cv2.INTER_LINEAR
        )

        # === Remap bbox into local crop coordinate space ===
        scale_x = TARGET_DIM[0] / (local_box[2] - local_box[0])
        scale_y = TARGET_DIM[1] / (local_box[3] - local_box[1])

        mapped_bbox = [
            max(0,              int((x1 - local_box[0]) * scale_x)),
            max(0,              int((y1 - local_box[1]) * scale_y)),
            min(TARGET_DIM[0],  int((x2 - local_box[0]) * scale_x)),
            min(TARGET_DIM[1],  int((y2 - local_box[1]) * scale_y))
        ]

        annotated = draw_bbox(
            flow_local_resized,
            mapped_bbox,
            caption=ped_id,
            thickness=2,
            color=(255, 0, 0)
        )

        cv2.imshow("Optical Flow Local + BBox", annotated)

        if SAVE_OUTPUT:
            out_path = os.path.join(
                ped_outdir,
                f"frame_{frame_idx}_flow_bbox_local.jpg"
            )
            cv2.imwrite(out_path, annotated)

        prev_frame = frame

        key = cv2.waitKey(1)
        if key == ord("q"):
            break

    cv2.destroyAllWindows()
    print(f"Finished local flow {subset}/{ped_id}")


if __name__ == "__main__":
    subsets = ["FN", "FP", "TP", "TN"]
    for subset in subsets:
        if subset == "FN":
            ped_set = fn_occ_top_30
        elif subset == "FP":
            ped_set = fp_occ_top_30
        elif subset == "TP":
            ped_set = tp_occ_combined
        elif subset == "TN":
            ped_set = tn_occ_combined
        else:
            ped_set = []

        for ped in tqdm(ped_set, desc=f"Processing {subset}"):
            extract_flow_frames_local(
                subset=subset,
                ped_id=ped,
                frames_to_show=32
            )

    print("Optical flow local extraction complete.")
# Out:
# c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Raft_Large_Weights.C_T_SKHT_V2`. You can also use `weights=Raft_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Processing FN:   0%|          | 0/30 [00:00<?, ?it/s]
# Processing local optical flow FN → 3_5_396
# Processing FN:   3%|▎         | 1/30 [01:18<37:59, 78.61s/it]
# Finished local flow FN/3_5_396
# Processing local optical flow FN → 3_6_433
# Processing FN:   3%|▎         | 1/30 [02:17<1:06:21, 137.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 197
#     194         ped_set = []
#     196     for ped in tqdm(ped_set, desc=f"Processing {subset}"):
# --> 197         extract_flow_frames_local(
#     198             subset=subset,
#     199             ped_id=ped,
#     200             frames_to_show=32
#     201         )
#     203 print("Optical flow local extraction complete.")
#
# Cell In[8], line 121, in extract_flow_frames_local(subset, ped_id, frames_to_show)
#     119 # === Compute RAFT on full frames — preserves scene-level motion context ===
#     120 ref_frame = prev_frame if prev_frame is not None else frame
# --> 121 flow_full = compute_raft_optical_flow(
#     122     preprocess_frame(ref_frame),
#     123     preprocess_frame(frame)
#     124 )
#     126 # Resize flow output to match full frame dimensions
#     127 flow_full_resized = cv2.resize(
#     128     flow_full,
#     129     (frame_w, frame_h),
#     130     interpolation=cv2.INTER_LINEAR
#     131 )
#
# Cell In[8], line 50, in compute_raft_optical_flow(prev_frame, next_frame)
#      48 def compute_raft_optical_flow(prev_frame, next_frame):
#      49     with torch.no_grad():
# ---> 50         flow     = raft_model(prev_frame.unsqueeze(0), next_frame.unsqueeze(0))[-1]
#      51         flow_img = flow_to_image(flow[0]).byte().permute(1, 2, 0).cpu().numpy()
#      52     return flow_img
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torchvision\models\optical_flow\raft.py:529, in RAFT.forward(self, image1, image2, num_flow_updates)
#     525 hidden_state, delta_flow = self.update_block(hidden_state, context, corr_features, flow)
#     527 coords1 = coords1 + delta_flow
# --> 529 up_mask = None if self.mask_predictor is None else self.mask_predictor(hidden_state)
#     530 upsampled_flow = upsample_flow(flow=(coords1 - coords0), up_mask=up_mask)
#     531 flow_predictions.append(upsampled_flow)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torchvision\models\optical_flow\raft.py:333, in MaskPredictor.forward(self, x)
#     331 def forward(self, x):
#     332     x = self.convrelu(x)
# --> 333     x = self.conv(x)
#     334     return self.multiplier * x
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\conv.py:553, in Conv2d.forward(self, input)
#     552 def forward(self, input: Tensor) -> Tensor:
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#     535 if self.padding_mode != "zeros":
#     536     return F.conv2d(
#     537         F.pad(
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    545         self.groups,
#     546     )
# --> 548 return F.conv2d(
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     550 )
#
# KeyboardInterrupt:

# %% [markdown]
# #### Categorical Depth (Local)

# %%
import os
import sys
import cv2
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm

from dataset.PIE_API import PIE
from tools.video_utils import VideoLoader
from tools.visualisation import draw_bbox
from tools.box_utils import jitter_bbox, squarify_bbox

# === CONFIGURATION ===
DATASET_DIR = r"C:\Users\dthq657\OneDrive - University of Leeds\Research\Datasets\PIE"
CLIPS_DIR   = os.path.join(DATASET_DIR, "PIE_clips")
DB_PATH     = os.path.join(DATASET_DIR, "data_cache", "pie_database.pkl")

SAVE_DIR    = "../Categorical-Depth"
os.makedirs(SAVE_DIR, exist_ok=True)

SAVE_OUTPUT = False

ATTR_CSVS = {
    "FN": "../Data-Prep/annot-data/PIE_annot_attrb_val_fn.csv",
    "FP": "../Data-Prep/annot-data/PIE_annot_attrb_val_fp.csv",
    "TP": "../Data-Prep/annot-data/PIE_annot_attrb_val_tp.csv",
    "TN": "../Data-Prep/annot-data/PIE_annot_attrb_val_tn.csv"
}

# === DEPTH MODEL ===
sys.path.insert(0, os.path.join(os.getcwd(), "feature", "manydepth"))
from _interface import DepthEstimator

Depth = DepthEstimator(
    model_path=os.path.join(os.getcwd(), "feature", "manydepth", "CityScapes_MR"),
    intrinsics_json_path=os.path.join(os.getcwd(), "feature", "manydepth", "PIE_intrinsics.json")
)

# === PIE DATABASE ===
if not os.path.isfile(DB_PATH):
    print("Generating PIE database...")
    dataset = PIE(data_path=DATASET_DIR)
    dataset.generate_database()

data = pickle.load(open(DB_PATH, "rb"))


def extract_depth_frames_local(subset="FP", ped_id="3_2_295", frames_to_show=32):

    print(f"Processing depth local {subset} → {ped_id}")

    attr_df = pd.read_csv(ATTR_CSVS[subset])
    row     = attr_df[attr_df["id"] == ped_id]

    if len(row) == 0:
        print("Pedestrian not found in CSV")
        return

    critical_point = int(row["critical_point"].iloc[0])

    set_id, vid_id, ped_num = ped_id.split("_")
    set_name   = f"set0{set_id[-1]}" if not set_id.startswith("set") else set_id
    video_name = f"video_{int(vid_id):04d}"

    video_path = os.path.join(CLIPS_DIR, set_name, f"{video_name}.mp4")
    video      = VideoLoader(video_path)

    annots = data[set_name][video_name]["ped_annotations"].get(ped_id)
    frames = annots["frames"]

    crit_idx   = frames.index(critical_point)
    start_idx  = max(0, crit_idx - (frames_to_show - 1))
    seq_frames = frames[start_idx:crit_idx + 1]

    ped_outdir = os.path.join(SAVE_DIR, f"{subset}/{ped_id}_depth_local")
    if SAVE_OUTPUT:
        os.makedirs(ped_outdir, exist_ok=True)

    TARGET_DIM    = (224, 224)
    sampling_time = -1
    source_image  = None

    for frame_idx in seq_frames:
        frame = video[frame_idx]
        t     = annots["frames"].index(frame_idx)
        bbox  = list(map(int, annots["bbox"][t][0:4]))

        # === Source image cadence — mirrors depth extraction script ===
        sampling_time += 1
        if (sampling_time == 0) or (not sampling_time % 7):
            source_image = frame.copy()

        # === Run depth model on full frame ===
        depth_list    = Depth.run(source_image, frame)
        depth_heatmap = cv2.cvtColor(depth_list[1], cv2.COLOR_BGR2RGB)
        depth_heatmap = cv2.resize(depth_heatmap, (frame.shape[1], frame.shape[0]))

        # === Overlay depth heatmap on original frame ===
        overlay = cv2.addWeighted(frame, 0.1, depth_heatmap, 0.9, 0)

        frame_h, frame_w = frame.shape[:2]
        x1, y1, x2, y2  = bbox

        # === Local context crop — jitter + squarify matching model input pipeline ===
        jitter_box = jitter_bbox(video.size, [bbox.copy()], mode="enlarge", ratio=1.0)[0]
        local_box  = squarify_bbox(jitter_box, 1.0, frame_w)
        local_box  = tuple(map(int, local_box[0:4]))

        crop_region = overlay[
            local_box[1]:local_box[3],
            local_box[0]:local_box[2]
        ]
        
        # Resize cropped region to 224x224
        crop_region_resized = cv2.resize(
            crop_region,
            TARGET_DIM,
            interpolation=cv2.INTER_LINEAR
        )

        # === Remap bbox into local crop coordinate space ===
        scale_x = TARGET_DIM[0] / (local_box[2] - local_box[0])
        scale_y = TARGET_DIM[1] / (local_box[3] - local_box[1])

        mapped_bbox = [
            max(0,              int((x1 - local_box[0]) * scale_x)),
            max(0,              int((y1 - local_box[1]) * scale_y)),
            min(TARGET_DIM[0],  int((x2 - local_box[0]) * scale_x)),
            min(TARGET_DIM[1],  int((y2 - local_box[1]) * scale_y))
        ]

        annotated = draw_bbox(
            crop_region_resized,
            mapped_bbox,
            caption=ped_id,
            thickness=2,
            color=(255, 0, 0)
        )

        cv2.imshow("Depth Local + BBox", annotated)

        if SAVE_OUTPUT:
            out_path = os.path.join(
                ped_outdir,
                f"frame_{frame_idx}_depth_bbox_local.jpg"
            )
            cv2.imwrite(out_path, annotated)

        key = cv2.waitKey(1)
        if key == ord("q"):
            break

    cv2.destroyAllWindows()
    print(f"Finished depth local {subset}/{ped_id}")


if __name__ == "__main__":
    subsets = ["FN", "FP", "TP", "TN"]
    for subset in subsets:
        if subset == "FN":
            ped_set = fn_occ_top_30
        elif subset == "FP":
            ped_set = fp_occ_top_30
        elif subset == "TP":
            ped_set = tp_occ_combined
        elif subset == "TN":
            ped_set = tn_occ_combined
        else:
            ped_set = []

        for ped in tqdm(ped_set, desc=f"Processing {subset}"):
            extract_depth_frames_local(
                subset=subset,
                ped_id=ped,
                frames_to_show=32
            )

    print("Depth local extraction complete.")
# Out:
# -> Loading model from  c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\manydepth\CityScapes_MR
#    Loading pretrained encoder
# c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\serialization.py:1832: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   result = unpickler.load()
# c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torchvision\models\_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#    Loading pretrained decoder
#    Loading pose network
# Processing FN:   0%|          | 0/30 [00:00<?, ?it/s]
# Processing depth local FN → 3_5_396
# Processing FN:   3%|▎         | 1/30 [00:12<05:55, 12.24s/it]
# Finished depth local FN/3_5_396
# Processing depth local FN → 3_6_433
# Processing FN:   7%|▋         | 2/30 [00:23<05:29, 11.78s/it]
# Finished depth local FN/3_6_433
# Processing depth local FN → 3_4_356
# Processing FN:   7%|▋         | 2/30 [00:32<07:38, 16.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 173
#     170         ped_set = []
#     172     for ped in tqdm(ped_set, desc=f"Processing {subset}"):
# --> 173         extract_depth_frames_local(
#     174             subset=subset,
#     175             ped_id=ped,
#     176             frames_to_show=32
#     177         )
#     179 print("Depth local extraction complete.")
#
# Cell In[9], line 95, in extract_depth_frames_local(subset, ped_id, frames_to_show)
#      92     source_image = frame.copy()
#      94 # === Run depth model on full frame ===
# ---> 95 depth_list    = Depth.run(source_image, frame)
#      96 depth_heatmap = cv2.cvtColor(depth_list[1], cv2.COLOR_BGR2RGB)
#      97 depth_heatmap = cv2.resize(depth_heatmap, (frame.shape[1], frame.shape[0]))
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\manydepth\_interface.py:111, in DepthEstimator.run(self, source_image, target_image)
#     106 # Load input data
#     107 input_image, original_size = self.load_and_preprocess_image(target_image,
#     108                                                     resize_width=self.encoder_dict['width'],
#     109                                                     resize_height=self.encoder_dict['height'])
# --> 111 source_image, _ = self.load_and_preprocess_image(source_image,
#     112                                             resize_width=self.encoder_dict['width'],
#     113                                             resize_height=self.encoder_dict['height'])
#     115 K, invK = self.load_and_preprocess_intrinsics(self.intrinsics_json_path,
#     116                                         resize_width=self.encoder_dict['width'],
#     117                                         resize_height=self.encoder_dict['height'])
#     119 with torch.no_grad():
#     120
#     121     # Estimate poses
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\manydepth\_interface.py:78, in DepthEstimator.load_and_preprocess_image(self, image, resize_width, resize_height)
#      76 image = pil.fromarray(image).convert('RGB')
#      77 original_width, original_height = image.size
# ---> 78 image = image.resize((resize_width, resize_height), pil.LANCZOS)
#      79 image = transforms.ToTensor()(image).unsqueeze(0)
#      80 if torch.cuda.is_available():
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\PIL\Image.py:2323, in Image.resize(self, size, resample, box, reducing_gap)
#    2311         self = (
#    2312             self.reduce(factor, box=reduce_box)
#    2313             if callable(self.reduce)
#    2314             else Image.reduce(self, factor, box=reduce_box)
#    2315         )
#    2316         box = (
#    2317             (box[0] - reduce_box[0]) / factor_x,
#    2318             (box[1] - reduce_box[1]) / factor_y,
#    2319             (box[2] - reduce_box[0]) / factor_x,
#    2320             (box[3] - reduce_box[1]) / factor_y,
#    2321         )
# -> 2323 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %% [markdown]
# #### Semantic Segmentation (Global)

# %%
import os
import cv2
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm

from dataset.PIE_API import PIE
from tools.video_utils import VideoLoader
from tools.visualisation import draw_bbox
from feature.DeepLabV3Plus._interface import SemanticEstimator


# CONFIGURATION
DATASET_DIR = r"C:\Users\dthq657\OneDrive - University of Leeds\Research\Datasets\PIE"
CLIPS_DIR = os.path.join(DATASET_DIR, "PIE_clips")
DB_PATH = os.path.join(
    DATASET_DIR,
    "data_cache",
    "pie_database.pkl"
)

SAVE_DIR = "../Full-Scale-Semantic"
os.makedirs(SAVE_DIR, exist_ok=True)

SAVE_OUTPUT = False

ATTR_CSVS = {
    "FN": "../Data-Prep/annot-data/PIE_annot_attrb_val_fn.csv",
    "FP": "../Data-Prep/annot-data/PIE_annot_attrb_val_fp.csv",
    "TP": "../Data-Prep/annot-data/PIE_annot_attrb_val_tp.csv",
    "TN": "../Data-Prep/annot-data/PIE_annot_attrb_val_tn.csv"
}

# LOAD SEMANTIC SEGMENTATION MODEL
CHECKPOINT = os.path.join(
    os.getcwd(),
    "feature",
    "DeepLabV3Plus",
    "checkpoints",
    "best_deeplabv3plus_resnet101_cityscapes_os16.pth"
)

Semantic = SemanticEstimator(ckpt=CHECKPOINT)

# LOAD PIE DATABASE
if not os.path.isfile(DB_PATH):
    print("Generating PIE database...")
    dataset = PIE(data_path=DATASET_DIR)
    dataset.generate_database()

data = pickle.load(open(DB_PATH, "rb"))

# FULL-SCALE SEMANTIC EXTRACTION FUNCTION
def extract_semantic_frames_fullscale(
    subset="FP",
    ped_id="3_2_295",
    frames_to_show=32
):
    print(f"Processing semantic full-scale {subset} → {ped_id}")

    # Load attribute metadata
    attr_df = pd.read_csv(ATTR_CSVS[subset])
    row = attr_df[attr_df["id"] == ped_id]
    if len(row) == 0:
        print("Pedestrian not found in CSV")
        return

    # Determine temporal window relative to prediction moment
    critical_point = int(row["critical_point"].iloc[0])
    set_id, vid_id, ped_num = ped_id.split("_")
    set_name = f"set0{set_id[-1]}" if not set_id.startswith("set") else set_id
    video_name = f"video_{int(vid_id):04d}"
    video_path = os.path.join(
        CLIPS_DIR,
        set_name,
        f"{video_name}.mp4"
    )

    video = VideoLoader(video_path)
    annots = data[set_name][video_name]["ped_annotations"].get(ped_id)
    frames = annots["frames"]
    crit_idx = frames.index(critical_point)
    start_idx = max(0, crit_idx - (frames_to_show - 1))
    seq_frames = frames[start_idx:crit_idx + 1]

    # Match bbox pipeline directory structure
    ped_outdir = os.path.join(
        SAVE_DIR,
        subset,
        f"{ped_id}_full"
    )

    if SAVE_OUTPUT:
        os.makedirs(ped_outdir, exist_ok=True)

    # Target output resolution (same as bbox full-scale)
    TARGET_W = 1280
    TARGET_H = 720

    for frame_idx in seq_frames:
        frame = video[frame_idx]
        t = annots["frames"].index(frame_idx)
        bbox = list(map(int, annots["bbox"][t][0:4]))
        frame_h, frame_w = frame.shape[:2]

        # Aspect ratio preserving resize
        scale = min(
            TARGET_W / frame_w,
            TARGET_H / frame_h
        )

        out_w = int(frame_w * scale)
        out_h = int(frame_h * scale)

        frame_resized = cv2.resize(
            frame,
            (out_w, out_h),
            interpolation=cv2.INTER_AREA
        )

        # Run semantic segmentation on resized frame
        semantic_map = Semantic.run(frame_resized)
        semantic_map = cv2.resize(
            semantic_map,
            (out_w, out_h),
            interpolation=cv2.INTER_NEAREST
        )

        # Overlay segmentation on RGB image
        overlay = cv2.addWeighted(
            frame_resized,
            0.45,
            semantic_map,
            0.55,
            0
        )

        # Scale bounding box coordinates
        scaled_bbox = [
            int(bbox[0] * scale),
            int(bbox[1] * scale),
            int(bbox[2] * scale),
            int(bbox[3] * scale)
        ]

        annotated = draw_bbox(
            overlay,
            scaled_bbox,
            caption=ped_id,
            thickness=2,
            color=(255, 0, 0)
        )

        cv2.imshow(
            "Semantic Full Scene + BBox",
            annotated
        )

        # Save output with consistent filename pattern
        if SAVE_OUTPUT:
            out_path = os.path.join(
                ped_outdir,
                f"frame_{frame_idx}_sem_bbox_full.jpg"
            )

            cv2.imwrite(
                out_path,
                annotated
            )


        key = cv2.waitKey(1)
        if key == ord("q"):
            break

    cv2.destroyAllWindows()
    print(f"Finished semantic full-scale {subset}/{ped_id}")

# BATCH EXTRACTION LOOP
if __name__ == "__main__":
    subsets = ["FN", "FP", "TP", "TN"]
    for subset in subsets:
        if subset == "FN": ped_set = fn_occ_top_30
        elif subset == "FP": ped_set = fp_occ_top_30
        elif subset == "TP": ped_set = tp_occ_combined
        elif subset == "TN": ped_set = tn_occ_combined
        else:  ped_set = []

        for ped in tqdm(ped_set,desc=f"Processing {subset}"):
            extract_semantic_frames_fullscale(
                subset=subset,
                ped_id=ped,
                frames_to_show=32
            )

    print("Semantic full-scale extraction complete.")
# Out:
# Device: cpu
# Resume model from c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\DeepLabV3Plus\checkpoints\best_deeplabv3plus_resnet101_cityscapes_os16.pth
# Processing FN:   0%|          | 0/30 [00:00<?, ?it/s]
# Processing semantic full-scale FN → 3_5_396
# Processing FN:   3%|▎         | 1/30 [00:59<28:57, 59.92s/it]
# Finished semantic full-scale FN/3_5_396
# Processing semantic full-scale FN → 3_6_433
# Processing FN:   3%|▎         | 1/30 [01:11<34:20, 71.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 191
#     188     else:  ped_set = []
#     190     for ped in tqdm(ped_set,desc=f"Processing {subset}"):
# --> 191         extract_semantic_frames_fullscale(
#     192             subset=subset,
#     193             ped_id=ped,
#     194             frames_to_show=32
#     195         )
#     197 print("Semantic full-scale extraction complete.")
#
# Cell In[11], line 123, in extract_semantic_frames_fullscale(subset, ped_id, frames_to_show)
#     116 frame_resized = cv2.resize(
#     117     frame,
#     118     (out_w, out_h),
#     119     interpolation=cv2.INTER_AREA
#     120 )
#     122 # Run semantic segmentation on resized frame
# --> 123 semantic_map = Semantic.run(frame_resized)
#     124 semantic_map = cv2.resize(
#     125     semantic_map,
#     126     (out_w, out_h),
#     127     interpolation=cv2.INTER_NEAREST
#     128 )
#     130 # Overlay segmentation on RGB image
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\DeepLabV3Plus\_interface.py:98, in SemanticEstimator.run(self, img)
#      96 img = transform(img).unsqueeze(0) # To tensor of NCHW
#      97 img = img.to(self.device)
# ---> 98 pred = self.model(img).max(1)[1].cpu().numpy()[0] # HW
#      99 colorized_preds = self.decode_fn(pred).astype('uint8')
#     100 colorized_preds = Image.fromarray(colorized_preds)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\parallel\data_parallel.py:176, in DataParallel.forward(self, *inputs, **kwargs)
#     174 with torch.autograd.profiler.record_function("DataParallel.forward"):
#     175     if not self.device_ids:
# --> 176         return self.module(*inputs, **kwargs)
#     178     # pyrefly: ignore [bad-argument-type]
#     179     for t in chain(self.module.parameters(), self.module.buffers()):
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\DeepLabV3Plus\network\utils.py:15, in _SimpleSegmentationModel.forward(self, x)
#      13 def forward(self, x):
#      14     input_shape = x.shape[-2:]
# ---> 15     features = self.backbone(x)
#      16     x = self.classifier(features)
#      17     x = F.interpolate(x, size=input_shape, mode='bilinear', align_corners=False)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\DeepLabV3Plus\network\utils.py:80, in IntermediateLayerGetter.forward(self, x)
#      78         x.append(module(x[-1]))
#      79 else: # other models (ex:resnet,mobilenet) are convolutions in series.
# ---> 80     x = module(x)
#      82 if name in self.return_layers:
#      83     out_name = self.return_layers[name]
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\feature\DeepLabV3Plus\network\backbone\resnet.py:101, in Bottleneck.forward(self, x)
#      98 def forward(self, x):
#      99     identity = x
# --> 101     out = self.conv1(x)
#     102     out = self.bn1(out)
#     103     out = self.relu(out)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\conv.py:553, in Conv2d.forward(self, input)
#     552 def forward(self, input: Tensor) -> Tensor:
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\pip-env\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#     535 if self.padding_mode != "zeros":
#     536     return F.conv2d(
#     537         F.pad(
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    545         self.groups,
#     546     )
# --> 548 return F.conv2d(
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     550 )
#
# KeyboardInterrupt:

# %% [markdown]
# #### Bounding Box (Global)

# %%
import os
import cv2
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm

from dataset.PIE_API import PIE
from tools.video_utils import VideoLoader
from tools.visualisation import draw_bbox
from tools.box_utils import jitter_bbox, squarify_bbox

# CONFIGURATION
DATASET_DIR = r"C:\Users\dthq657\OneDrive - University of Leeds\Research\Datasets\PIE"
CLIPS_DIR = os.path.join(DATASET_DIR, "PIE_clips")
DB_PATH = os.path.join(DATASET_DIR, "data_cache", "pie_database.pkl")

TARGET_DIM = (224, 224)

SAVE_DIR = "../Full-Scale-BBox"
os.makedirs(SAVE_DIR, exist_ok=True)

SAVE_OUTPUT = False   #### TOGGLE SAVE

ATTR_CSVS = {
    "FN": "../Data-Prep/annot-data/PIE_annot_attrb_val_fn.csv",
    "FP": "../Data-Prep/annot-data/PIE_annot_attrb_val_fp.csv",
    "TP": "../Data-Prep/annot-data/PIE_annot_attrb_val_tp.csv",
    "TN": "../Data-Prep/annot-data/PIE_annot_attrb_val_tn.csv"
}

# LOAD PIE DATABASE
if not os.path.isfile(DB_PATH):
    print("Generating PIE database...")
    dataset = PIE(data_path=DATASET_DIR)
    dataset.generate_database()

data = pickle.load(open(DB_PATH, "rb"))

def extract_bbox_frames_fullscale(subset="FP", ped_id="3_2_295", frames_to_show=32):

    print(f"Processing full-scale {subset} → {ped_id}")

    attr_df = pd.read_csv(ATTR_CSVS[subset])
    row = attr_df[attr_df["id"] == ped_id]

    if len(row) == 0:
        print("Pedestrian not found in CSV")
        return

    critical_point = int(row["critical_point"].iloc[0])

    set_id, vid_id, ped_num = ped_id.split("_")
    set_name = f"set0{set_id[-1]}" if not set_id.startswith("set") else set_id
    video_name = f"video_{int(vid_id):04d}"

    video_path = os.path.join(CLIPS_DIR, set_name, f"{video_name}.mp4")
    video = VideoLoader(video_path)

    annots = data[set_name][video_name]["ped_annotations"].get(ped_id)
    frames = annots["frames"]

    crit_idx = frames.index(critical_point)
    start_idx = max(0, crit_idx - (frames_to_show - 1))
    seq_frames = frames[start_idx:crit_idx + 1]

    ped_outdir = os.path.join(SAVE_DIR, f"{subset}/{ped_id}_full_scale")
    if SAVE_OUTPUT:
        os.makedirs(ped_outdir, exist_ok=True)

    # Target output resolution — change here to adjust file size
    TARGET_W = 1280
    TARGET_H = 720

    for frame_idx in seq_frames:
        frame = video[frame_idx]
        t = annots["frames"].index(frame_idx)
        bbox = list(map(int, annots["bbox"][t][0:4]))

        frame_h, frame_w = frame.shape[:2]

        # Aspect-ratio-preserving downscale
        scale = min(TARGET_W / frame_w, TARGET_H / frame_h)
        out_w = int(frame_w * scale)
        out_h = int(frame_h * scale)

        frame_resized = cv2.resize(frame, (out_w, out_h), interpolation=cv2.INTER_AREA)

        # Remap bbox to scaled coordinates
        scaled_bbox = [
            int(bbox[0] * scale),
            int(bbox[1] * scale),
            int(bbox[2] * scale),
            int(bbox[3] * scale)
        ]

        annotated = draw_bbox(
            frame_resized,
            scaled_bbox,
            caption=ped_id,
            thickness=2,
            color=(255, 0, 0)
        )

        cv2.imshow("Full Scene + BBox", annotated)

        if SAVE_OUTPUT:
            out_path = os.path.join(
                ped_outdir,
                f"frame_{frame_idx}_bbox_fullscale.jpg"
            )
            cv2.imwrite(out_path, annotated)

        key = cv2.waitKey(1)
        if key == ord("q"):
            break

    cv2.destroyAllWindows()
    print(f"Finished full-scale {subset}/{ped_id}")

if __name__ == "__main__":
    subsets = ["FN", "FP", "TP", "TN"]
    for subset in subsets:
        if subset == "FN": ped_set = fn_occ_top_30
        elif subset == "FP": ped_set = fp_occ_top_30
        elif subset == "TP": ped_set = tp_occ_combined
        elif subset == "TN": ped_set = tn_occ_combined
        else:  ped_set = []

        for ped in tqdm(ped_set, desc=f"Processing {subset}"):
            extract_bbox_frames_fullscale(
                subset=subset,
                ped_id=ped,
                frames_to_show=32
            )

    print("Full-scale BBox frame extraction complete.")
# Out:
# Processing FN:   0%|          | 0/30 [00:00<?, ?it/s]
# Processing full-scale FN → 3_5_396
# Processing FN:   3%|▎         | 1/30 [00:03<01:53,  3.92s/it]
# Finished full-scale FN/3_5_396
# Processing full-scale FN → 3_6_433
# Processing FN:   7%|▋         | 2/30 [00:08<01:53,  4.06s/it]
# Finished full-scale FN/3_6_433
# Processing full-scale FN → 3_4_356
# Processing FN:   7%|▋         | 2/30 [00:08<02:02,  4.36s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 131
#     128     else:  ped_set = []
#     130     for ped in tqdm(ped_set, desc=f"Processing {subset}"):
# --> 131         extract_bbox_frames_fullscale(
#     132             subset=subset,
#     133             ped_id=ped,
#     134             frames_to_show=32
#     135         )
#     137 print("Full-scale BBox frame extraction complete.")
#
# Cell In[12], line 76, in extract_bbox_frames_fullscale(subset, ped_id, frames_to_show)
#      73 TARGET_H = 720
#      75 for frame_idx in seq_frames:
# ---> 76     frame = video[frame_idx]
#      77     t = annots["frames"].index(frame_idx)
#      78     bbox = list(map(int, annots["bbox"][t][0:4]))
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\tools\video_utils.py:49, in VideoLoader.__getitem__(self, key)
#      47     if key < 0:
#      48         key += self.length
# ---> 49     return self.get_frame(key)
#      50 else:
#      51     raise TypeError(f"Invalid key type: {key}. Use int or slice.")
#
# File c:\Users\dthq657\Desktop\Project Files\Github\PIPVIS-Image-Base\Image-Prep\tools\video_utils.py:72, in VideoLoader.get_frame(self, frame_number)
#      70 else:
#      71     if 0 <= frame_number < self.length:
# ---> 72         self.capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
#      73         ret, frame = self.capture.read()
#      74         if ret:
#
# KeyboardInterrupt:
